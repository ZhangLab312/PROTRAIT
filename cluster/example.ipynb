# %%
from cluster.clustering import Clustering
import torch
# data prepare
content = torch.load("../performance/pth/protrait.pth", map_location=torch.device("cpu"))
dense = content['prediction.linear.weight']
dense = dense.cpu().numpy()

# cluster
umap_data, pred_labels = Clustering.louvain_clustering(data=dense)
Clustering.visualization(umap_data, pred_labels)
